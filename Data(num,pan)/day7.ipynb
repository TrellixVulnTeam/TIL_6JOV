# %% [markdown]
# ## 히스토그램

# %%
import seaborn as sns 
tips=sns.load_dataset('tips')

# %%
import matplotlib.pyplot as plt

# %%
ax=plt.subplots
ax=sns.distplot(tips['total_bill'])

# %%
ax=plt.subplots
ax=sns.distplot(tips['total_bill'],kde=False) #히스토그램과 확률밀도 그래프 출력됨
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %%
ax=plt.subplots
ax=sns.distplot(tips['total_bill'],kde=False, hist=False) #히스토그램과 확률밀도 그래프 출력됨
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Freq')
# Out:
# Text(0, 0.5, 'Freq')

# %%
ax=plt.subplots
ax=sns.distplot(tips['total_bill'],rug=True) #히스토그램과 확률밀도 그래프 출력됨
ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Freq')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Freq')

# %%
ax=plt.subplots
ax=sns.countplot(tips['day']) #히스토그램과 확률밀도 그래프 출력됨
ax.set_title('count of days')
ax.set_xlabel('day of the week')
ax.set_ylabel('frequency')
# Out:
# Text(0, 0.5, 'frequency')

# %%
ax=plt.subplots
ax=sns.countplot(tips['day']) #히스토그램과 확률밀도 그래프 출력됨
#ax.set_title('Total Bill Histogram')
#ax.set_xlabel('Total Bill')
#ax.set_ylabel('Freq')

# %% [markdown]
# ## 이변량 그래프

# %%
ax=plt.subplots
ax=sns.regplot(x='total_bill' ,y='tip' ,data=tips) #히스토그램과 확률밀도 그래프 출력됨
ax.set_title('scatterplot')
ax.set_xlabel('Total Bill')
ax.set_ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %%
ax=plt.subplots
ax=sns.regplot(x='total_bill' ,y='tip' ,data=tips, fit_reg=False) #히스토그램과 확률밀도 그래프 출력됨
ax.set_title('scatterplot')
ax.set_xlabel('Total Bill')
ax.set_ylabel('tip')
# Out:
# Text(0, 0.5, 'tip')

# %% [markdown]
# ## jointplot

# %%
#ax=plt.subplots()  #jointplot함수 내에서 자체적으로 plot생성한다
ax=sns.jointplot(x='total_bill' ,y='tip' ,data=tips) #히스토그램과 확률밀도 그래프 출력됨

# %%
ax=sns.jointplot(x='total_bill' ,y='tip' ,data=tips,kind='hex')  #점의 모양 변경

# %% [markdown]
# ## 밀집도 그래프

# %%
ax=plt.subplots()
sns.kdeplot(data=tips['total_bill'],data2=tips['tip'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:1639: FutureWarning: Use `x` and `y` rather than `data` `and `data2`
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
ax=plt.subplots()
sns.kdeplot(data=tips['total_bill'],data2=tips['tip'], shade=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:1639: FutureWarning: Use `x` and `y` rather than `data` `and `data2`
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## barplot: 막대그래프

# %%
ax=plt.subplots
ax=sns.barplot(x='time' ,y='total_bill' ,data=tips) 
ax.set_title('barplot')
ax.set_xlabel('time')
ax.set_ylabel('total_bill')
# Out:
# Text(0, 0.5, 'total_bill')

# %% [markdown]
# ## violinplot

# %%
ax=plt.subplots
ax=sns.violinplot(x='time' ,y='total_bill' ,data=tips) 
ax.set_title('barplot')
ax.set_xlabel('time')
ax.set_ylabel('total_bill')
# Out:
# Text(0, 0.5, 'total_bill')

# %% [markdown]
# ## pairplot

# %%
sns.pairplot(tips)

# %% [markdown]
# ## PariGrid

# %%
pairGrid=sns.PairGrid(tips)
pairGrid=pairGrid.map_upper(sns.regplot)  #위쪽 3부분
pairGrid=pairGrid.map_lower(sns.kdeplot)
pairGrid=pairGrid.map_diag(sns.displot, rug=True)
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/seaborn/distributions.py:2164: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try histplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## hue옵션 !! 중요

# %%
sns.lmplot(x='total_bill',y='tip', data=tips)

# %%
sns.lmplot(x='total_bill',y='tip', data=tips,fit_reg=False)

# %%
sns.lmplot(x='total_bill',y='tip', data=tips,fit_reg=False, hue='day')

# %%
sns.lmplot(x='total_bill',y='tip', data=tips,fit_reg=False, hue='sex')

# %%
sns.pairplot(tips,hue='sex')

# %%
sns.lmplot(x='total_bill',y='tip', data=tips,fit_reg=False, hue='day')

# %% [markdown]
# ## scatter_kws: 점의 크기 변경 옵션

# %%
ax = plt.subplots() 
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False, scatter_kws={'s':tips['size']*10}) 
ax.set_title('Scatterplot of Total Bill and Tip') 
ax.set_xlabel('Total Bill') 
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
sns.lmplot(x='total_bill',y='tip', data=tips,fit_reg=False, hue='day',
           scatter_kws={'s': 5})

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
# %matplotlib inline
#노트북 내부에 그림 출력
plt.plot([1,4,9,16])
plt.show()

# %%
# %matplotlib inline
#노트북 내부에 그림 출력
plt.plot([10,20,30,40],[1,4,9,16])
plt.show()  #주피터 노트북 이외에 꼭 필요함

# %%
plt.rcParams['font.family'] = 'AppleGothic'

# %%
plt.title('한글 제목')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel("엑스축 라벨")
plt.ylabel("와이축 라벨")
plt.show()

# %%
plt.title("'rs--' 스타일의 plot ")
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], 'rs--')
plt.show()

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="b",
         lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.title("스타일 적용 예")
plt.show()

# %%
plt.plot([10, 20, 30, 40], [1, 4, 9, 16], c="r",
         lw=3, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.title("스타일 적용 예")
plt.xlim(0, 50)
plt.ylim(-10, 30)  #x축과 y축 범위 설정
plt.show()

# %%
import numpy as np

# %%
x=np.linspace(-np.pi, np.pi, 256)  #지정된 구간을 256개로 나눈다
y=np.cos(x)

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.xticks([-np.pi,-np.pi/2,0,np.pi/2, np.pi])
plt.yticks([-1,0,1])
plt.show()
# Out:
# ([<matplotlib.axis.YTick at 0x7f8579f0baf0>,
# ...
#  [Text(0, -1, 'Low'), Text(0, 0, 'Zero'), Text(0, 1, 'High')])

# %%
#latex 수학 문자식
plt.xticks([-np.pi, -np.pi / 2, 0, np.pi / 2, np.pi],
           [r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])
plt.yticks([-1, 0, 1], ["Low", "Zero", "High"])
# Out:
# ([<matplotlib.axis.YTick at 0x7f857a615670>,
# ...
#  [Text(0, -1, 'Low'), Text(0, 0, 'Zero'), Text(0, 1, 'High')])

# %% [markdown]
# ## 여러 개 선 출력

# %%
t=np.arange(0,5,0.2)
t
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4,
#        2.6, 2.8, 3. , 3.2, 3.4, 3.6, 3.8, 4. , 4.2, 4.4, 4.6, 4.8])

# %%
plt.plot(t,t,'r--',t,0.5*t**2,'bs:')

# %%
plt.plot(t,t,'r--',t,0.5*t**2,'bs:',t,0.5*t**3,'g^-')

# %% [markdown]
# ## 범례설정하기

# %%
plt.plot([1, 4, 9, 16],

         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r",label='blue')

plt.plot([9, 16, 4, 1],
         c="k", lw=3, ls=":", marker="s", ms=10, mec="m", mew=5, mfc="c",label='black')


plt.legend(loc=2)

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.title("legend를 표시한 플롯")
plt.plot(X, C, ls="--", label="cosine")
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc=2)   #0~10까지 있음, 디폴트가 0(가장 좋은 위치를 찾아서 배치시킴)
plt.xlabel('time')
plt.ylabel('amp')

plt.show()

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10, 2))
plt.title("figure size : (10, 2)")
plt.plot(np.random.randn(100))
plt.show()

# %%
f1 = plt.figure(figsize=(5,4))
plt.title("현재의 Figure 객체")
plt.plot([1, 2, 3, 4], 'ro:')


f2=plt.gcf()
print(f2, id(f2))  #figure객체 크기, id
# Out:
# Figure(360x288) 140210757861136

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(2, 1, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2, 1, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
# Out:
# Text(0, 0.5, 'Undamped')

# %%
#f1=figure(figsize=(10,6))

x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

ax1 = plt.subplot(1, 2, 1)
plt.plot(x1, y1, 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(1, 2, 2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
# Out:
# Text(0, 0.5, 'Undamped')

# %%
np.random.seed(0)

plt.subplot(221)
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")



#축값이랑 겹치지 않게 하기 위해
plt.tight_layout()

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## twinx(): 여러개의 y값을 만들 때(여러개의 y값을 공유하는 x축)

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.set_title("2개의 y축 한 figure에서 사용하기")
ax0.plot([10, 5, 2, 9, 7], 'r-', label="y0")
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g:', label="y1")
ax1.set_ylabel("y1")
ax1.grid(False)
ax0.set_xlabel("공유되는 x축")
plt.show()

# %%
import matplotlib as mpl
import matplotlib.pylab as plt

y = [2, 3, 1]
x = np.arange(len(y))
xlabel = ['가', '나', '다']
plt.title("Bar Chart")
plt.bar(x, y)
plt.xticks(x, xlabel)
plt.yticks(sorted(y))
plt.xlabel("가나다")
plt.ylabel("빈도 수")
plt.show()

# %%
x = np.linspace(0.1, 2 * np.pi, 10)
plt.title("Stem Plot")
plt.stem(x, np.cos(x), '-.')
plt.show()

# %%
labels = ['개구리', '돼지', '개', '통나무']
sizes = [15, 30, 45, 10]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
explode = (0, 0.5, 0, 0)
plt.title("Pie Chart")
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.2f%%', shadow=True, startangle=90)
plt.axis('equal')   #%는 %문자 출력할때 소수점 설정,1.2는 소수점 2자리
plt.show()

# %%
pip install ipython
# Out:
# ...
# WARNING: You are using pip version 21.0; however, version 21.0.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from Ipython.display import YouTubeVideo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-121-bd6c6406287a> in <module>
# ----> 1 from Ipython.display import YouTubeVideo
#
# ModuleNotFoundError: No module named 'Ipython'

# %%
#YouTubeVideo('ncfgAQ1542k', width=800, height=450)

# %%
N = 30
np.random.seed(0)
x = np.random.rand(N)
y1 = np.random.rand(N)
y2 = np.random.rand(N)
y3 = np.pi * (15 * np.random.rand(N))**2
plt.title("Bubble Chart")
plt.scatter(x, y1, c=y2, s=y3)
plt.show()

# %%
#tsne, pca 차원 축소(고->저)

# %%
from sklearn.datasets import load_digits

# %%
digits=load_digits()

# %%
digits
# Out:
# {'data': array([[ 0.,  0.,  5., ...,  0.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 10.,  0.,  0.],
#         [ 0.,  0.,  0., ..., 16.,  9.,  0.],
#         ...,
#         [ 0.,  0.,  1., ...,  6.,  0.,  0.],
#         [ 0.,  0.,  2., ..., 12.,  0.,  0.],
#         [ 0.,  0., 10., ..., 12.,  1.,  0.]]),
#  'target': array([0, 1, 2, ..., 8, 9, 8]),
#  'frame': None,
#  'feature_names': ['pixel_0_0',
#   'pixel_0_1',
#   'pixel_0_2',
#   'pixel_0_3',
#   'pixel_0_4',
#   'pixel_0_5',
#   'pixel_0_6',
#   'pixel_0_7',
#   'pixel_1_0',
#   'pixel_1_1',
#   'pixel_1_2',
#   'pixel_1_3',
#   'pixel_1_4',
#   'pixel_1_5',
#   'pixel_1_6',
#   'pixel_1_7',
#   'pixel_2_0',
#   'pixel_2_1',
#   'pixel_2_2',
#   'pixel_2_3',
#   'pixel_2_4',
#   'pixel_2_5',
#   'pixel_2_6',
#   'pixel_2_7',
#   'pixel_3_0',
#   'pixel_3_1',
#   'pixel_3_2',
#   'pixel_3_3',
#   'pixel_3_4',
#   'pixel_3_5',
#   'pixel_3_6',
#   'pixel_3_7',
#   'pixel_4_0',
#   'pixel_4_1',
#   'pixel_4_2',
#   'pixel_4_3',
# ...

# %%
digits.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'feature_names', 'target_names', 'images', 'DESCR'])

# %%
digits.images
digits.images.shape  #1797장 이미지, 8*8크기
# Out:
# (1797, 8, 8)

# %%
digits.images[0]
# Out:
# array([[ 0.,  0.,  5., 13.,  9.,  1.,  0.,  0.],
#        [ 0.,  0., 13., 15., 10., 15.,  5.,  0.],
#        [ 0.,  3., 15.,  2.,  0., 11.,  8.,  0.],
#        [ 0.,  4., 12.,  0.,  0.,  8.,  8.,  0.],
#        [ 0.,  5.,  8.,  0.,  0.,  9.,  8.,  0.],
#        [ 0.,  4., 11.,  0.,  1., 12.,  7.,  0.],
#        [ 0.,  2., 14.,  5., 10., 12.,  0.,  0.],
#        [ 0.,  0.,  6., 13., 10.,  0.,  0.,  0.]])

# %%
#퀴즈 :위의 배열은 -->0

# %%
digits.images[1]
# Out:
# array([[ 0.,  0.,  0., 12., 13.,  5.,  0.,  0.],
#        [ 0.,  0.,  0., 11., 16.,  9.,  0.,  0.],
#        [ 0.,  0.,  3., 15., 16.,  6.,  0.,  0.],
#        [ 0.,  7., 15., 16., 16.,  2.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 16.,  3.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 16.,  6.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 16.,  6.,  0.,  0.],
#        [ 0.,  0.,  0., 11., 16., 10.,  0.,  0.]])

# %%
digits.images[2]
# Out:
# array([[ 0.,  0.,  0.,  4., 15., 12.,  0.,  0.],
#        [ 0.,  0.,  3., 16., 15., 14.,  0.,  0.],
#        [ 0.,  0.,  8., 13.,  8., 16.,  0.,  0.],
#        [ 0.,  0.,  1.,  6., 15., 11.,  0.,  0.],
#        [ 0.,  1.,  8., 13., 15.,  1.,  0.,  0.],
#        [ 0.,  9., 16., 16.,  5.,  0.,  0.,  0.],
#        [ 0.,  3., 13., 16., 16., 11.,  5.,  0.],
#        [ 0.,  0.,  0.,  3., 11., 16.,  9.,  0.]])

# %%
x=digits.images[1]
x
# Out:
# array([[ 0.,  0.,  0., 12., 13.,  5.,  0.,  0.],
#        [ 0.,  0.,  0., 11., 16.,  9.,  0.,  0.],
#        [ 0.,  0.,  3., 15., 16.,  6.,  0.,  0.],
#        [ 0.,  7., 15., 16., 16.,  2.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 16.,  3.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 16.,  6.,  0.,  0.],
#        [ 0.,  0.,  1., 16., 16.,  6.,  0.,  0.],
#        [ 0.,  0.,  0., 11., 16., 10.,  0.,  0.]])

# %%
plt.title("mnist digits; 1")
plt.imshow(x, interpolation='nearest', cmap=plt.cm.bone_r)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.subplots_adjust(left=0.35, right=0.65, bottom=0.35, top=0.65)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(-3,3,100)
y1=np.sin(x)
y2=np.cos(x)
y3=1/(1+np.exp(-x))
y4=np.exp(x)

fig, ax = plt.subplots(2, 2)

ax[0, 0].plot(x, y1)
ax[0, 1].plot(x, y2)
ax[1, 0].plot(x, y3)
ax[1, 1].plot(x,y4)

ax[0, 0].set_title("Sine function")
ax[0, 1].set_title("Cosine function")
ax[1, 0].set_title("Sigmoid function")
ax[1, 1].set_title("Exponential function")


#여백주기

#fig.tight_layout()()
plt.subplots_adjust(wspace=0.2,hspace=0.5,
                   left=0.125,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9,)

# %%
methods = [
    None, 'none', 'nearest', 'bilinear', 'bicubic', 'spline16',
    'spline36', 'hanning', 'hamming', 'hermite', 'kaiser', 'quadric',
    'catrom', 'gaussian', 'bessel', 'mitchell', 'sinc', 'lanczos'
]
fig, axes = plt.subplots(3, 6, figsize=(12, 6),
                         subplot_kw={'xticks': [], 'yticks': []})
for ax, interp_method in zip(axes.flat, methods):
    ax.imshow(x, cmap=plt.cm.bone_r, interpolation=interp_method)
    ax.set_title(interp_method)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-164-b95d6b9d0b44> in <module>
#       7                          subplot_kw={'xticks': [], 'yticks': []})
#       8 for ax, interp_method in zip(axes.flat, methods):
# ----> 9     ax.imshow(x, cmap=plt.cm.bone_r, interpolation=interp_method)
#      10     ax.set_title(interp_method)
#      11 plt.show()
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
fig, axes = plt.subplots(1, 4, figsize=(12, 3),
                         subplot_kw={'xticks': [], 'yticks': []})
axes[0].set_title("plt.cm.Blues")
axes[0].imshow(x, interpolation='nearest', cmap=plt.cm.Blues)
axes[1].set_title("plt.cm.Blues_r")
axes[1].imshow(x, interpolation='nearest', cmap=plt.cm.Blues_r)
axes[2].set_title("plt.BrBG")
axes[2].imshow(x, interpolation='nearest', cmap='BrBG')
axes[3].set_title("plt.BrBG_r")
axes[3].imshow(x, interpolation='nearest', cmap='BrBG_r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-165-a5e204e765ed> in <module>
#       2                          subplot_kw={'xticks': [], 'yticks': []})
#       3 axes[0].set_title("plt.cm.Blues")
# ----> 4 axes[0].imshow(x, interpolation='nearest', cmap=plt.cm.Blues)
#       5 axes[1].set_title("plt.cm.Blues_r")
#       6 axes[1].imshow(x, interpolation='nearest', cmap=plt.cm.Blues_r)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
iris = sns.load_dataset("iris")    # 붓꽃 데이터
titanic = sns.load_dataset("titanic")    # 타이타닉호 데이터
tips = sns.load_dataset("tips")    # 팁 데이터
flights = sns.load_dataset("flights")    # 여객운송 데이터

# %%
x=iris.petal_length.values

# %%
sns.rugplot(x)
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(x)
plt.title("Iris 데이터 중, 꽃잎의 길이에 대한 Kernel Density Plot")
plt.show()

# %%
sns.distplot(x, kde=True, rug=True)
plt.title("Iris 데이터 중, 꽃잎의 길이에 대한 Dist Plot")
plt.show()

# %%
sns.countplot(x="day", data=tips)
plt.title("요일별 팁을 준 횟수")
plt.show()

# %%
sns.pairplot(iris,hue='species',markers=['o','s','d'])
